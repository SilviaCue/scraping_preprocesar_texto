# %% [markdown]
# *****Procesamiento de lenguaje Natural (NLP)*****

# %% [markdown]
# *Ejemplo spacy, BeautifulSoup*

# %%
# !pip install -U spacy
# instalación el paquete español más simple (MB aproximadamente)
# !python -m spacy download es_core_news_md
# Out:
# Requirement already satisfied: spacy in c:\users\silvi\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\silvi\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\silvi\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\silvi\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\silvi\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\silvi\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\silvi\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\silvi\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\silvi\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\silvi\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\silvi\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Collecting es-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.7.0/es_core_news_md-3.7.0-py3-none-any.whl (42.3 MB)
#      ---------------------------------------- 0.0/42.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/42.3 MB 660.6 kB/s eta 0:01:04
#      ---------------------------------------- 0.3/42.3 MB 3.5 MB/s eta 0:00:12
#       --------------------------------------- 0.6/42.3 MB 4.3 MB/s eta 0:00:10
#       --------------------------------------- 0.9/42.3 MB 5.4 MB/s eta 0:00:08
#      - -------------------------------------- 1.3/42.3 MB 5.8 MB/s eta 0:00:08
#      - -------------------------------------- 1.7/42.3 MB 6.5 MB/s eta 0:00:07
#      - -------------------------------------- 2.1/42.3 MB 6.6 MB/s eta 0:00:07
#      -- ------------------------------------- 2.4/42.3 MB 6.5 MB/s eta 0:00:07
#      -- ------------------------------------- 2.9/42.3 MB 6.9 MB/s eta 0:00:06
#      --- ------------------------------------ 3.4/42.3 MB 7.5 MB/s eta 0:00:06
#      --- ------------------------------------ 3.9/42.3 MB 7.7 MB/s eta 0:00:05
#      ---- ----------------------------------- 4.4/42.3 MB 7.9 MB/s eta 0:00:05
#      ---- ----------------------------------- 4.8/42.3 MB 8.1 MB/s eta 0:00:05
#      ----- ---------------------------------- 5.4/42.3 MB 8.4 MB/s eta 0:00:05
#      ----- ---------------------------------- 5.9/42.3 MB 8.6 MB/s eta 0:00:05
#      ------ --------------------------------- 6.4/42.3 MB 8.7 MB/s eta 0:00:05
#      ------ --------------------------------- 6.8/42.3 MB 8.9 MB/s eta 0:00:04
#      ------ --------------------------------- 7.1/42.3 MB 8.5 MB/s eta 0:00:05
#      ------- -------------------------------- 7.6/42.3 MB 8.7 MB/s eta 0:00:04
#      ------- -------------------------------- 8.2/42.3 MB 8.9 MB/s eta 0:00:04
#      -------- ------------------------------- 8.9/42.3 MB 9.2 MB/s eta 0:00:04
#      --------- ------------------------------ 9.6/42.3 MB 9.4 MB/s eta 0:00:04
#      --------- ----------------------------- 10.4/42.3 MB 10.2 MB/s eta 0:00:04
#      --------- ----------------------------- 10.8/42.3 MB 10.7 MB/s eta 0:00:03
#      ---------- ---------------------------- 11.4/42.3 MB 10.9 MB/s eta 0:00:03
#      ----------- --------------------------- 12.2/42.3 MB 11.3 MB/s eta 0:00:03
#      ----------- --------------------------- 12.9/42.3 MB 11.9 MB/s eta 0:00:03
#      ------------ -------------------------- 13.2/42.3 MB 11.7 MB/s eta 0:00:03
#      ------------ -------------------------- 13.9/42.3 MB 11.9 MB/s eta 0:00:03
#      ------------- ------------------------- 14.6/42.3 MB 12.1 MB/s eta 0:00:03
MB 11.3 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.1/42.3 MB 11.1 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.9/42.3 MB 11.1 MB/s eta 0:00:01
#      ----------------------------------- --- 38.5/42.3 MB 11.1 MB/s eta 0:00:01
#      ------------------------------------ -- 39.2/42.3 MB 11.5 MB/s eta 0:00:01
#      ------------------------------------ -- 39.8/42.3 MB 11.5 MB/s eta 0:00:01
#      ------------------------------------- - 40.5/42.3 MB 11.7 MB/s eta 0:00:01
#      --------------------------------------  41.2/42.3 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  41.9/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  42.3/42.3 MB 12.6 MB/s eta 0:00:01
#      ---------------------------------------- 42.3/42.3 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\silvi\anaconda3\lib\site-packages (from es-core-news-md==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\silvi\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\silvi\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\silvi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\silvi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\silvi\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\silvi\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\silvi\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\silvi\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\silvi\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\silvi\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\silvi\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\silvi\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\silvi\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\silvi\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.1.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
import requests
from bs4 import BeautifulSoup
import spacy
import csv

# %%
#carga idioma español written text (news, media) 
nlp= spacy.load('es_core_news_md')

# %%
# Función para conseguir contenido página web
def get_webpage_content(url):
    response= requests.get(url)
    if response.status_code ==200:
        return response.text
    else:
        return None

# %%
#Función para limpiar , extraer texto de la web
def extract_text_from_html(html_content):
    soup=BeautifulSoup(html_content, 'html.parser')
    paragraphs = soup.find_all('p')
    return ''.join([para.get_text() for para in paragraphs])

# %%
# Función para análisis de texto
def analyze_text(url, csv_filename):
    html_content = get_webpage_content(url)
    if html_content:
        text = extract_text_from_html(html_content)
        doc = nlp(text)
        
        # Mostrar estadísticas básicas
        print(f"Texto extraído (primeros 500 caracteres):\n{text[:500]}")
        
        # Calcular el número de palabras
        word_list = [token.text for token in doc if token.is_alpha]
        num_words = len(word_list)
        print(f"Número de palabras: {num_words}")
        print(f"Número de entidades nombradas: {len(doc.ents)}\n")
        
        unique_entities = set()
        for ent in doc.ents:
            unique_entities.add((ent.text, ent.label_))
            
        # Guardar las entidades nombradas en un archivo CSV
        with open(csv_filename, mode="w", encoding="utf-8", newline='') as csv_file:
            writer = csv.writer(csv_file)
            writer.writerow(["Entidad", "Etiqueta"])
            
            # Escribir entidades únicas en el archivo CSV
            for entity in unique_entities:
                writer.writerow(entity)
    
    else:
        print("No se pudo obtener el contenido de la página")

# URL de ejemplo
url = "https://es.wikipedia.org/wiki/Inteligencia_artificial"
csv_filename = "entidades_text.csv"

if __name__ == "__main__":
    analyze_text(url, csv_filename)
# Out:
# Texto extraído (primeros 500 caracteres):
# La inteligencia artificial  (IA), en el contexto de las ciencias de la computación, es una disciplina y un conjunto de capacidades cognoscitivas e intelectuales expresadas por sistemas informáticos o combinaciones de algoritmos cuyo propósito es la creación de máquinas que imiten la inteligencia humana para realizar tareas, y que pueden mejorar conforme recopilen información.[1]​[2]​ Se hizo presente poco después de la Segunda Guerra Mundial con el desarrollo de la «prueba de Turing», mientras q
# Número de palabras: 7082
# Número de entidades nombradas: 257
